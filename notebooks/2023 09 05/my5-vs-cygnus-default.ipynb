# %% [markdown]
# # my5-vs-cygnus-default
# 8/29/2023
#
# Compare Cygnus to my5.
# - Using new Naboo scripts
# - Using default build config (100M warmup + 200M sim)

# %%
import os
import sys
sys.path.append(os.path.abspath("../../"))

from collections import defaultdict
from importlib import reload
from matplotlib import colormaps
import pandas as pd
# from utils import plots, stats, tables, utils

from plot_utils import collate, plot

# %% [markdown]
# # Configuration

# %%
sim_dir = "/u/cmolder/GitHub/ChampSim/sim/default"
baseline_study = "stu_prefetchers"
baseline_experiment = "_baseline"
weights_path = "/u/cmolder/GitHub/ChampSim/naboo/conf/weights.toml"

suites = [
    "spec06",
    "spec17",
    "cloudsuite",
    "gap",
    "gap_real"
]
stats  = [
    "cpu.gmean.ipc_improvement",
]
dpi = 150

# %%
reload(collate)
studies = {
    # Baseline
    "stu_prefetchers": collate.StudyCollator(sim_dir, "stu_prefetchers", 
                                             baseline_study=baseline_study, 
                                             baseline_experiment=baseline_experiment,
                                             weights_path=weights_path),
}
# Out:
# [ipykernel_launcher][angrist-3] Reading study files: 100%|██████████| 3608/3608 [00:40<00:00, 88.45file/s]
# [ipykernel_launcher][angrist-3] Generating benchmark stats for 121 benchmarks over 11 experiments:
#     Benchmarks : pr__amazon0601.mtx bc__coAuthorsDBLP.mtx cc__wikipedia-20060925.mtx lbm bwaves pr__coPapersDBLP.mtx cc__cnr-2000.mtx pr__coAuthorsCiteseer.mtx bc bc__sx-stackoverflow_A2Q.mtx delta bc__in-2004.mtx pr__luxembourg_osm.mtx sphinx3 bfs__netherlands_osm.mtx cc__flickr.mtx pr__eu-2005.mtx cc__citationCiteseer.mtx bc__wiki-topcats.mtx cc__com-Youtube.mtx 649.fotonik3d charlie cc__sx-stackoverflow_A2Q.mtx xalancbmk pr__citationCiteseer.mtx cc__soc-LiveJournal1.mtx pr__web-Google.mtx pr__in-2004.mtx bc__citationCiteseer.mtx pr__flickr.mtx pr__amazon-2008.mtx cc__dblp-2010.mtx pr__sx-stackoverflow_C2Q.mtx milc pr__netherlands_osm.mtx GemsFDTD cc__wiki-topcats.mtx cc bc__sx-stackoverflow_C2Q.mtx 627.cam4 classifcation bfs__belgium_osm.mtx pr__coPapersCiteseer.mtx gcc bfs__citationCiteseer.mtx pr tc bc__netherlands_osm.mtx cc__in-2004.mtx bc__amazon0601.mtx pr__sx-stackoverflow_A2Q.mtx pr__sx-stackoverflow_C2A.mtx bc__web-Google.mtx pr__dblp-2010.mtx cc__sx-stackoverflow_C2A.mtx cactusADM leslie3d cc__web-Google.mtx cassandra bfs__coAuthorsCiteseer.mtx bc__flickr.mtx bc__wikipedia-20060925.mtx libquantum pr__cnr-2000.mtx zeusmp cc__amazon-2008.mtx bfs__web-Google.mtx cc__belgium_osm.mtx pr__com-Youtube.mtx pr__soc-LiveJournal1.mtx bc__sx-stackoverflow_C2A.mtx cloud9 bfs__coAuthorsDBLP.mtx bc__dblp-2010.mtx nutch cc__coPapersDBLP.mtx bc__sx-stackoverflow.mtx cc__wikipedia-20051105.mtx bfs__sx-stackoverflow_C2A.mtx 607.cactuBSSN cc__coPapersCiteseer.mtx bc__luxembourg_osm.mtx pr__wiki-topcats.mtx bfs__in-2004.mtx bc__coPapersCiteseer.mtx pr__sx-stackoverflow.mtx merced bfs 605.mcf whiskey bc__coPapersDBLP.mtx pr__coAuthorsDBLP.mtx pr__wikipedia-20060925.mtx pr__wikipedia-20051105.mtx 602.gcc bfs__amazon0601.mtx 628.pop2 cc__amazon0601.mtx bc__soc-LiveJournal1.mtx bc__com-Youtube.mtx bc__wikipedia-20051105.mtx cc__sx-stackoverflow.mtx 620.omnetpp 619.lbm 623.xalancbmk astar mcf bc__amazon-2008.mtx bc__coAuthorsCiteseer.mtx bfs__sx-stackoverflow_A2Q.mtx pr__belgium_osm.mtx bfs__dblp-2010.mtx bfs__sx-stackoverflow_C2Q.mtx cc__netherlands_osm.mtx bc__belgium_osm.mtx omnetpp sssp bfs__amazon-2008.mtx bfs__com-Youtube.mtx soplex cc__sx-stackoverflow_C2Q.mtx
#     Experiments: pf_mlop pf_spp pf_dspatch pf_cygnus_depth pf_pythia pf_sms pf_spp_ppf pf_my5 pf_bingo pf_cygnus _baseline
# [ipykernel_launcher][angrist-3] Generating benchmark stats: 100%|██████████| 1331/1331 [00:05<00:00, 235.56it/s]
# [ipykernel_launcher][angrist-3] Generating suite stats for 7 suites over 11 experiments:
#     Suites     : google cloudsuite all spec17 gap gap_real spec06
#     Experiments: pf_mlop pf_spp pf_dspatch pf_cygnus_depth pf_pythia pf_sms pf_spp_ppf pf_my5 pf_bingo pf_cygnus _baseline
# [ipykernel_launcher][angrist-3] Generating suite stats: 100%|██████████| 77/77 [00:06<00:00, 11.65it/s]

# %% [markdown]
# # Dynamic degree

# %%
degreedyn_1core_df = {
    'Cygnus':       studies['stu_prefetchers']['pf_cygnus'],
    'Cygnus Depth': studies['stu_prefetchers']['pf_cygnus_depth'],
    'Pythia':       studies['stu_prefetchers']['pf_pythia'],
    #'Bingo':   studies['stu_prefetchers']['pf_bingo'],
    #'SMS':     studies['stu_prefetchers']['pf_sms'],
    #'SPP':     studies['stu_prefetchers']['pf_spp'],
    'SPP+PPF': studies['stu_prefetchers']['pf_spp_ppf'],
    #'MLOP':    studies['stu_prefetchers']['pf_mlop'],
    #'DSPatch': studies['stu_prefetchers']['pf_dspatch'],
    'my5':     studies['stu_prefetchers']['pf_my5'],
}
degreedyn_1core_colors = defaultdict(lambda: None, {
    'Cygnus':       colormaps['Set3'](0), #cmaps['Cygnus-Width'](0.65),
    'Cygnus Depth': colormaps['Set3'](1), #cmaps['Cygnus-Ignore'](0.65),
    'Pythia':       colormaps['Set3'](2), #cmaps['Pythia'](0.65),
    #'Pythia +Ignore':                    #cmaps['Pythia-Ignore'](0.65),
    #'Pythia Width':                      #cmaps['Pythia-Width'](0.5),
    'Bingo':    colormaps['Set3'](3), #'purple',
    'SMS':      colormaps['Set3'](4), #'royalblue',
    'SPP':      colormaps['Set3'](5), #'royalblue',
    'SPP+PPF':  colormaps['Set3'](6), #'darkturquoise',
    'MLOP':     colormaps['Set3'](7), #'deeppink',
    'DSPatch':  colormaps['Set3'](8), #'darkred',
    'my5': colormaps['Set3'](9), #'gold',
})

degreedyn_1core_legend_kwargs = {
    'ncol': 4,
    'fontsize': 6.75,
    'loc': 'lower center',
    'bbox_to_anchor': (0.5, 1.0),
    'framealpha': 0,
}

degreedyn_1core_legend_kwargs_wide = {
    'ncol': 8,
    'fontsize': 6.75,
    'loc': 'lower center',
    'bbox_to_anchor': (0.5, 1.0),
    'framealpha': 0,
}

degreedyn_1core_label_kwargs = {
    'rotation': 0,
    'ha': 'center',
    'fontsize': 7,
}

# %% [markdown]
# ## IPC improvement

# %%
reload(plot)
plot.get_suite_table(
    degreedyn_1core_df, "cpu.gmean.ipc_improvement",
    suites=suites, add_mean=True)
# Out:
#               spec06  spec17  cloudsuite    gap  gap_real      gmean
# Cygnus         31.47   17.49        3.87  27.47     12.90  18.218086
# Cygnus Depth   25.50   14.94        5.67  24.47     11.29  16.122798
# Pythia         24.46   15.89        4.79  24.27     11.29  15.889372
# SPP+PPF        29.32   17.33        3.80  23.95     11.60  16.852113
# my5            32.40   19.48        6.40  23.13     11.83  18.306718

# %%
reload(plot)
plot.plot_suite_statistic(
    degreedyn_1core_df, "cpu.gmean.ipc_improvement",
    suites=suites,
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='gmean IPC improvement (%)',
    ylim=(0, 50),
    ytick_distance=5,
    dpi=192, figsize=(5, 2.7))

# %% [markdown]
# ### spec06

# %%
reload(plot)
plot.get_benchmark_table(
    degreedyn_1core_df, "spec06", "cpu.gmean.ipc_improvement",
    add_mean=True).T
# Out:
#                 Cygnus  Cygnus Depth     Pythia     SPP+PPF         my5
# GemsFDTD     55.760000     28.000000  26.500000   40.010000   63.630000
# astar         6.720000      6.530000   6.410000    6.500000    2.080000
# bwaves      116.950000     77.610000  67.260000   99.220000   62.510000
# cactusADM    50.420000     44.990000  44.760000   49.580000   41.690000
# gcc          28.690000     19.490000  17.760000   23.860000   25.320000
# lbm          15.970000     17.110000  15.860000   18.150000   14.040000
# leslie3d     43.680000     33.310000  29.670000   36.660000   43.150000
# libquantum   85.580000     69.940000  96.030000  109.310000  115.760000
# mcf          14.020000     14.340000  14.210000    9.120000   18.080000
# milc          1.840000      1.590000   1.660000   10.750000   19.480000
# omnetpp       1.480000      5.370000   2.630000    1.250000   19.550000
# soplex       21.940000     19.580000  19.360000   20.440000   14.320000
# sphinx3      42.840000     41.080000  25.830000   35.180000   53.820000
# xalancbmk    10.370000      8.000000   7.370000    7.140000   10.920000
# zeusmp       23.850000     21.530000  22.610000   19.180000   20.510000
# gmean        31.466125     25.498319  24.458863   29.320143   32.394555

# %%
reload(plot)
plot.plot_benchmark_statistic(
    degreedyn_1core_df, "spec06", "cpu.gmean.ipc_improvement",
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='IPC improvement (%)',
    ylim=(0, 120),
    ytick_distance=10,
    dpi=192, figsize=(10, 3))
# import matplotlib.pyplot as plt
# plt.savefig('../../cvs/papers/micro-23r/figures/results_summary.pdf')

# %% [markdown]
# ### gap

# %%
reload(plot)
plot.get_benchmark_table(
    degreedyn_1core_df, "gap", "cpu.gmean.ipc_improvement",
    add_mean=True).T
# Out:
#           Cygnus  Cygnus Depth     Pythia    SPP+PPF        my5
# bc     13.360000     12.900000  12.880000  12.470000  11.890000
# bfs    85.710000     65.160000  64.670000  67.510000  59.550000
# cc     36.030000     34.720000  33.930000  34.460000  35.480000
# pr      1.830000      1.790000   1.910000   1.400000   1.300000
# sssp   11.600000     11.770000  11.480000   9.700000   7.710000
# tc     31.810000     30.110000  30.220000  28.690000  32.040000
# gmean  27.468543     24.469226  24.270144  23.949084  23.127684

# %%
reload(plot)
plot.plot_benchmark_statistic(
    degreedyn_1core_df, "gap", "cpu.gmean.ipc_improvement",
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='IPC improvement (%)',
    ylim=(0, 120),
    ytick_distance=10,
    dpi=192, figsize=(5, 3))
# import matplotlib.pyplot as plt
# plt.savefig('../../cvs/papers/micro-23r/figures/results_summary.pdf')

# %% [markdown]
# ### gap_real

# %%
reload(plot)
pd.set_option('display.max_rows', 500)
plot.get_benchmark_table(
    degreedyn_1core_df, "gap_real", "cpu.gmean.ipc_improvement",
    add_mean=True).T
# Out:
#                                   Cygnus  Cygnus Depth    Pythia    SPP+PPF  \
# bc__amazon-2008.mtx             1.330000      2.130000   2.08000   2.010000
# bc__amazon0601.mtx             -1.100000     -1.000000  -0.99000  -0.160000
# bc__belgium_osm.mtx             3.890000      3.780000   3.85000   4.940000
# bc__citationCiteseer.mtx       -3.990000     -3.440000  -3.42000   1.770000
# bc__coAuthorsCiteseer.mtx      -0.810000      1.480000   1.44000   2.440000
# bc__coAuthorsDBLP.mtx          -1.130000     -0.010000  -0.13000   1.830000
# bc__coPapersCiteseer.mtx       11.990000     14.330000  14.34000  14.040000
# bc__coPapersDBLP.mtx            8.960000     12.250000  12.42000  11.170000
# bc__com-Youtube.mtx            -2.020000     -0.430000  -0.45000   1.550000
# bc__dblp-2010.mtx               4.530000      6.810000   6.71000   6.120000
# bc__flickr.mtx                  1.840000      3.400000   3.33000   3.740000
# bc__in-2004.mtx                13.190000     12.740000  12.82000  12.360000
# bc__luxembourg_osm.mtx         10.910000     10.390000  10.36000  11.300000
# bc__netherlands_osm.mtx         6.240000      5.100000   5.27000   5.400000
# bc__soc-LiveJournal1.mtx       -4.120000     -3.760000  -3.77000  -2.280000
# bc__sx-stackoverflow.mtx       -5.490000     -5.640000  -5.71000  -0.880000
# bc__sx-stackoverflow_A2Q.mtx   -5.140000     -4.730000  -4.77000  -0.450000
# bc__sx-stackoverflow_C2A.mtx   -3.680000     -3.350000  -3.43000   0.510000
# bc__sx-stackoverflow_C2Q.mtx   -5.200000     -4.970000  -5.05000  -0.530000
# bc__web-Google.mtx             -3.690000     -3.530000  -3.57000  -0.260000
# bc__wiki-topcats.mtx           -2.440000     -1.940000  -1.91000  -0.520000
# bc__wikipedia-20051105.mtx     -4.210000     -3.910000  -3.96000  -1.410000
# bc__wikipedia-20060925.mtx     -5.460000     -5.300000  -5.34000  -2.140000
# bfs__amazon-2008.mtx           38.310000     33.550000  34.51000  34.090000
# bfs__amazon0601.mtx            37.810000     32.810000  33.09000  32.660000
# bfs__belgium_osm.mtx            5.070000      4.560000   4.54000   6.800000
# bfs__citationCiteseer.mtx      42.090000     33.740000  31.76000  34.440000
# bfs__coAuthorsCiteseer.mtx     40.090000     33.390000  32.81000  33.820000
# bfs__coAuthorsDBLP.mtx         42.500000     35.280000  35.76000  35.840000
# bfs__com-Youtube.mtx           38.940000     32.750000  33.66000  35.390000
# bfs__dblp-2010.mtx             51.510000     46.200000  48.14000  48.600000
# bfs__in-2004.mtx               40.230000     35.280000  37.17000  39.070000
# bfs__netherlands_osm.mtx       10.340000      8.860000   8.60000   9.220000
# bfs__sx-stackoverflow_A2Q.mtx  23.100000     21.370000  21.29000  20.140000
# bfs__sx-stackoverflow_C2A.mtx  26.690000     23.770000  23.82000  22.700000
# bfs__sx-stackoverflow_C2Q.mtx  33.480000     29.950000  28.14000  28.020000
# bfs__web-Google.mtx            30.500000     28.490000  26.27000  27.420000
# cc__amazon-2008.mtx            20.370000     17.780000  17.42000  18.270000
# cc__amazon0601.mtx             16.820000     14.670000  14.43000  14.500000
# cc__belgium_osm.mtx            58.760000     50.700000  51.99000  55.300000
# cc__citationCiteseer.mtx       26.410000     23.290000  21.81000  21.090000
# cc__cnr-2000.mtx               25.290000     21.020000  20.95000  23.910000
# cc__coPapersCiteseer.mtx        1.360000      1.340000   1.18000   1.660000
# cc__coPapersDBLP.mtx            2.950000      2.340000   2.09000   2.770000
# cc__com-Youtube.mtx            31.070000     25.590000  26.27000  27.340000
# cc__dblp-2010.mtx              50.230000     41.040000  42.99000  44.560000
# cc__flickr.mtx                 10.720000      9.090000   9.08000   9.130000
# cc__in-2004.mtx                20.070000     16.750000  17.52000  18.720000
# cc__netherlands_osm.mtx        73.840000     57.520000  60.76000  61.470000
# cc__soc-LiveJournal1.mtx        6.060000      5.000000   5.03000   5.100000
# cc__sx-stackoverflow.mtx        5.270000      4.950000   4.84000   5.060000
# cc__sx-stackoverflow_A2Q.mtx    7.150000      6.730000   5.81000   7.540000
# cc__sx-stackoverflow_C2A.mtx   15.750000     14.440000  14.40000  14.950000
# cc__sx-stackoverflow_C2Q.mtx   11.620000     11.880000  11.40000  13.330000
# cc__web-Google.mtx             12.780000     11.300000  10.58000  12.290000
# cc__wiki-topcats.mtx            9.800000      7.870000   7.71000   8.720000
# cc__wikipedia-20051105.mtx      8.520000      6.720000   6.86000   7.590000
# cc__wikipedia-20060925.mtx      9.380000      7.560000   8.26000   8.240000
# pr__amazon-2008.mtx            14.570000     12.020000  11.42000   7.470000
# pr__amazon0601.mtx             11.550000     10.660000  10.64000   2.310000
# pr__belgium_osm.mtx            25.560000     21.440000  20.16000  19.210000
# pr__citationCiteseer.mtx        3.240000      3.170000   3.16000   0.850000
# pr__cnr-2000.mtx                9.780000      8.220000   7.99000   8.200000
# pr__coAuthorsCiteseer.mtx      14.060000     12.290000  12.10000   3.810000
# pr__coAuthorsDBLP.mtx          15.470000     13.850000  13.86000   3.640000
# pr__coPapersCiteseer.mtx       10.230000      6.660000   6.59000   8.420000
# pr__coPapersDBLP.mtx           13.750000      9.990000   9.95000  11.270000
# pr__com-Youtube.mtx            13.120000     11.070000  11.53000   5.640000
# pr__dblp-2010.mtx              23.640000     17.560000  17.14000  12.420000
# pr__eu-2005.mtx                10.610000      8.180000   8.37000   8.280000
# pr__flickr.mtx                  7.270000      6.650000   6.57000   3.370000
# pr__in-2004.mtx                 9.070000      7.990000   8.38000   8.240000
# pr__luxembourg_osm.mtx         44.630000     40.430000  40.25000  35.820000
# pr__netherlands_osm.mtx        47.860000     34.310000  35.63000  25.470000
# pr__soc-LiveJournal1.mtx        5.590000      5.440000   5.34000   3.280000
# pr__sx-stackoverflow.mtx       -5.720000     -5.550000  -5.66000  -1.220000
# pr__sx-stackoverflow_A2Q.mtx   -5.530000     -5.400000  -5.44000  -0.880000
# pr__sx-stackoverflow_C2A.mtx   -2.930000     -2.700000  -2.78000  -0.580000
# pr__sx-stackoverflow_C2Q.mtx   -6.680000     -6.410000  -6.41000  -1.230000
# pr__web-Google.mtx              1.560000      1.670000   1.67000   0.490000
# pr__wiki-topcats.mtx            7.700000      7.280000   7.06000   4.340000
# pr__wikipedia-20051105.mtx      1.060000      1.040000   1.04000   1.020000
# pr__wikipedia-20060925.mtx      1.670000      1.510000   1.54000   1.480000
# gmean                          12.904606     11.291217  11.28564  11.602053
#
#                                      my5
# bc__amazon-2008.mtx             2.000000
# bc__amazon0601.mtx              1.730000
# bc__belgium_osm.mtx             2.440000
# bc__citationCiteseer.mtx        2.950000
# bc__coAuthorsCiteseer.mtx       2.420000
# bc__coAuthorsDBLP.mtx           2.590000
# bc__coPapersCiteseer.mtx       14.010000
# bc__coPapersDBLP.mtx           13.300000
# bc__com-Youtube.mtx             2.180000
# bc__dblp-2010.mtx               4.290000
# bc__flickr.mtx                  4.610000
# bc__in-2004.mtx                10.690000
# bc__luxembourg_osm.mtx          4.780000
# bc__netherlands_osm.mtx         2.420000
# bc__soc-LiveJournal1.mtx        1.420000
# bc__sx-stackoverflow.mtx        0.870000
# bc__sx-stackoverflow_A2Q.mtx    0.990000
# bc__sx-stackoverflow_C2A.mtx    1.980000
# bc__sx-stackoverflow_C2Q.mtx    0.870000
# bc__web-Google.mtx              0.660000
# bc__wiki-topcats.mtx            1.060000
# bc__wikipedia-20051105.mtx      1.120000
# bc__wikipedia-20060925.mtx      1.260000
# bfs__amazon-2008.mtx           35.900000
# bfs__amazon0601.mtx            35.520000
# bfs__belgium_osm.mtx            2.000000
# bfs__citationCiteseer.mtx      36.950000
# bfs__coAuthorsCiteseer.mtx     36.410000
# bfs__coAuthorsDBLP.mtx         38.560000
# bfs__com-Youtube.mtx           37.600000
# bfs__dblp-2010.mtx             49.860000
# bfs__in-2004.mtx               38.780000
# bfs__netherlands_osm.mtx        3.870000
# bfs__sx-stackoverflow_A2Q.mtx  22.920000
# bfs__sx-stackoverflow_C2A.mtx  24.270000
# bfs__sx-stackoverflow_C2Q.mtx  30.000000
# bfs__web-Google.mtx            31.440000
# cc__amazon-2008.mtx            17.820000
# cc__amazon0601.mtx             15.220000
# cc__belgium_osm.mtx            59.680000
# cc__citationCiteseer.mtx       23.420000
# cc__cnr-2000.mtx               25.870000
# cc__coPapersCiteseer.mtx        2.050000
# cc__coPapersDBLP.mtx            3.160000
# cc__com-Youtube.mtx            28.590000
# cc__dblp-2010.mtx              45.010000
# cc__flickr.mtx                  9.010000
# cc__in-2004.mtx                20.270000
# cc__netherlands_osm.mtx        71.700000
# cc__soc-LiveJournal1.mtx        5.610000
# cc__sx-stackoverflow.mtx        5.540000
# cc__sx-stackoverflow_A2Q.mtx    8.380000
# cc__sx-stackoverflow_C2A.mtx   15.780000
# cc__sx-stackoverflow_C2Q.mtx   15.630000
# cc__web-Google.mtx             13.280000
# cc__wiki-topcats.mtx            9.670000
# cc__wikipedia-20051105.mtx      8.790000
# cc__wikipedia-20060925.mtx      9.020000
# pr__amazon-2008.mtx             1.440000
# pr__amazon0601.mtx              0.110000
# pr__belgium_osm.mtx            16.330000
# pr__citationCiteseer.mtx       -0.040000
# pr__cnr-2000.mtx                8.150000
# pr__coAuthorsCiteseer.mtx       0.200000
# pr__coAuthorsDBLP.mtx          -0.020000
# pr__coPapersCiteseer.mtx        2.860000
# pr__coPapersDBLP.mtx            1.680000
# pr__com-Youtube.mtx             3.660000
# pr__dblp-2010.mtx              11.790000
# pr__eu-2005.mtx                 6.630000
# pr__flickr.mtx                  2.650000
# pr__in-2004.mtx                 7.550000
# pr__luxembourg_osm.mtx         42.930000
# pr__netherlands_osm.mtx        37.680000
# pr__soc-LiveJournal1.mtx        0.950000
# pr__sx-stackoverflow.mtx        0.180000
# pr__sx-stackoverflow_A2Q.mtx    0.020000
# pr__sx-stackoverflow_C2A.mtx    0.100000
# pr__sx-stackoverflow_C2Q.mtx    0.010000
# pr__web-Google.mtx              0.230000
# pr__wiki-topcats.mtx           -0.470000
# pr__wikipedia-20051105.mtx      0.570000
# pr__wikipedia-20060925.mtx      1.000000
# gmean                          11.831574

# %% [markdown]
# ## IPC

# %%
degreedyn_1core_df_plus_baseline = {
    'Baseline':     studies['stu_prefetchers']['_baseline'],
    'Cygnus':       studies['stu_prefetchers']['pf_cygnus'],
    'Cygnus Depth': studies['stu_prefetchers']['pf_cygnus_depth'],
    'Pythia':       studies['stu_prefetchers']['pf_pythia'],
    #'Bingo':   studies['stu_prefetchers']['pf_bingo'],
    #'SMS':     studies['stu_prefetchers']['pf_sms'],
    #'SPP':     studies['stu_prefetchers']['pf_spp'],
    'SPP+PPF': studies['stu_prefetchers']['pf_spp_ppf'],
    #'MLOP':    studies['stu_prefetchers']['pf_mlop'],
    #'DSPatch': studies['stu_prefetchers']['pf_dspatch'],
    'my5':     studies['stu_prefetchers']['pf_my5'],
}

reload(plot)
plot.get_suite_table(
    degreedyn_1core_df_plus_baseline, "cpu.gmean.ipc",
    suites=suites, add_mean=True)
# Out:
#               spec06  spec17  cloudsuite   gap  gap_real     gmean
# Baseline        0.45    0.69        1.30  0.55      0.59  0.665954
# Cygnus          0.59    0.81        1.35  0.70      0.67  0.787352
# Cygnus Depth    0.56    0.79        1.37  0.68      0.66  0.770757
# Pythia          0.56    0.80        1.36  0.68      0.66  0.771568
# SPP+PPF         0.58    0.81        1.35  0.68      0.66  0.777786
# my5             0.59    0.82        1.38  0.67      0.66  0.783489

# %%
reload(plot)
plot.plot_suite_statistic(
    degreedyn_1core_df_plus_baseline, "cpu.gmean.ipc",
    suites=suites,
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='gmean IPC',
    ylim=(0, 2.0),
    ytick_distance=0.2,
    dpi=192, figsize=(5, 2.7))

# %% [markdown]
# ### spec06

# %%
reload(plot)
plot.get_benchmark_table(
    degreedyn_1core_df_plus_baseline, "spec06", "cpu.gmean.ipc",
    add_mean=True).T
# Out:
#             Baseline    Cygnus  Cygnus Depth    Pythia   SPP+PPF       my5
# GemsFDTD    0.270000  0.410000      0.340000  0.340000  0.370000  0.430000
# astar       0.400000  0.420000      0.420000  0.420000  0.420000  0.400000
# bwaves      0.420000  0.920000      0.750000  0.710000  0.840000  0.690000
# cactusADM   0.910000  1.370000      1.320000  1.320000  1.360000  1.290000
# gcc         0.550000  0.710000      0.660000  0.650000  0.680000  0.690000
# lbm         0.260000  0.300000      0.300000  0.300000  0.300000  0.290000
# leslie3d    0.440000  0.630000      0.580000  0.570000  0.600000  0.620000
# libquantum  0.410000  0.760000      0.700000  0.800000  0.860000  0.890000
# mcf         0.070000  0.080000      0.080000  0.080000  0.080000  0.080000
# milc        0.560000  0.570000      0.570000  0.570000  0.620000  0.670000
# omnetpp     0.400000  0.400000      0.420000  0.410000  0.400000  0.480000
# soplex      0.300000  0.360000      0.360000  0.360000  0.360000  0.340000
# sphinx3     0.800000  1.140000      1.120000  1.000000  1.080000  1.220000
# xalancbmk   0.850000  0.940000      0.920000  0.910000  0.910000  0.940000
# zeusmp      1.840000  2.280000      2.230000  2.250000  2.190000  2.210000
# gmean       0.449924  0.588877      0.562806  0.559314  0.580613  0.590995

# %%
reload(plot)
plot.plot_benchmark_statistic(
    degreedyn_1core_df_plus_baseline, "spec06", "cpu.gmean.ipc",
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='IPC',
    ylim=(0, 2.5),
    ytick_distance=0.2,
    dpi=192, figsize=(10, 3))

# %% [markdown]
# ## L2C accuracy

# %%
reload(plot)
plot.plot_suite_statistic(
    degreedyn_1core_df, "cache.L2C.amean.pf_timely_accuracy",
    secondary_statistic_name="cache.L2C.amean.pf_accuracy",
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='amean L2C prefetch accuracy (%)',
    ylim=(0, 100),
    ytick_distance=10,
    dpi=192, figsize=(5, 2.7))

# %% [markdown]
# ### spec06

# %%
reload(plot)
plot.get_benchmark_table(
    degreedyn_1core_df, "spec06", "cache.L2C.amean.pf_accuracy",
    add_mean=True).T
# Out:
#                Cygnus  Cygnus Depth      Pythia     SPP+PPF         my5
# GemsFDTD    83.900000     92.170000   92.660000   89.130000   96.370000
# astar       44.930000     60.090000   58.310000   52.320000   78.450000
# bwaves      98.470000     99.190000   99.440000   99.350000   99.900000
# cactusADM   99.580000     99.770000   99.920000   99.770000   99.790000
# gcc         35.240000     57.620000   57.350000   53.030000   73.200000
# lbm         99.920000     99.990000   99.990000   99.960000  100.000000
# leslie3d    93.920000     95.100000   97.800000   96.240000   97.360000
# libquantum  99.990000    100.000000  100.000000  100.000000  100.000000
# mcf         47.820000     48.120000   47.930000   47.780000   84.790000
# milc        56.710000     85.300000   83.160000   86.950000   99.940000
# omnetpp     34.810000     48.160000   44.940000   45.520000   73.070000
# soplex      54.780000     71.440000   70.080000   66.530000   72.310000
# sphinx3     59.020000     82.560000   82.950000   78.020000   90.580000
# xalancbmk   37.240000     55.220000   52.220000   48.120000   61.090000
# zeusmp      89.860000     94.270000   95.590000   86.540000   97.570000
# amean       69.079333     79.266667   78.822667   76.617333   88.294667

# %%
reload(plot)
plot.plot_benchmark_statistic(
    degreedyn_1core_df, "spec06", "cache.L2C.amean.pf_timely_accuracy",
    secondary_statistic_name="cache.L2C.amean.pf_accuracy",
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='L2C prefetch accuracy (%)',
    ylim=(0, 100),
    ytick_distance=10,
    dpi=192, figsize=(10, 3))

# %% [markdown]
# ## L2C coverage

# %%
reload(plot)
plot.plot_suite_statistic(
    degreedyn_1core_df, "cache.L2C.amean.pf_coverage",
    secondary_statistic_name="cache.L2C.amean.pf_untimely_coverage",
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='amean L2C prefetch coverage (%)',
    ylim=(0, 100),
    ytick_distance=10,
    dpi=192, figsize=(5, 2.7))

# %% [markdown]
# ### spec06

# %%
reload(plot)
plot.get_benchmark_table(
    degreedyn_1core_df, "spec06", "cache.L2C.amean.pf_coverage",
    add_mean=True).T
# Out:
#             Cygnus  Cygnus Depth  Pythia    SPP+PPF     my5
# GemsFDTD     80.21     73.120000   71.31  73.970000  65.300
# astar        14.82     15.460000   14.88  17.140000  13.510
# bwaves       66.19     55.480000   45.79  65.110000  30.080
# cactusADM    68.12     63.530000   61.38  67.420000  42.600
# gcc          38.94     27.950000   25.95  32.130000  31.010
# lbm          23.68     20.120000   19.25  23.280000  23.580
# leslie3d     56.77     51.220000   35.99  45.980000  46.070
# libquantum   54.04     53.250000   27.11  44.310000  35.090
# mcf          29.25     30.110000   29.90  11.520000  23.180
# milc         26.18     23.930000   17.72  25.540000  26.880
# omnetpp      39.18     23.190000   20.68  25.650000  36.650
# soplex       44.75     37.500000   34.43  34.190000  31.800
# sphinx3      72.61     63.820000   42.65  56.110000  59.150
# xalancbmk    26.71     16.750000   15.92  18.160000  19.520
# zeusmp       65.95     63.480000   60.24  54.770000  45.260
# amean        47.16     41.260667   34.88  39.685333  35.312

# %%
reload(plot)
plot.plot_benchmark_statistic(
    degreedyn_1core_df, "spec06", "cache.L2C.amean.pf_coverage",
    secondary_statistic_name="cache.L2C.amean.pf_untimely_coverage",
    add_mean=True,
    colors=degreedyn_1core_colors,
    legend_kwargs=degreedyn_1core_legend_kwargs,
    label_kwargs=degreedyn_1core_label_kwargs,
    add_suptitle=False,
    add_xlabel=False,
    ylabel='L2C prefetch coverage (%)',
    ylim=(0, 100),
    ytick_distance=10,
    dpi=192, figsize=(10, 3))
